# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("CKD.csv")

# %%
dataset
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# ...

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype=int)

# %%
dataset
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
independent=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]

# %%
independent.shape
# Out:
# (399, 27)

# %%
dependent=dataset[['classification_yes']]

# %%
dependent.shape
# Out:
# (399, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scalar= StandardScaler()
X_train = scalar.fit_transform(X_train)
X_test = scalar.transform(X_test)

# %%
from sklearn.svm import SVC

# %%
from sklearn.model_selection import GridSearchCV
param_grid ={'kernel':['linear','rbf','poly','sigmoid'],'gamma':['auto','scale'],'C':[10.100,1000,2000,3000]}
grid = GridSearchCV(SVC(probability=True), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 
grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [10.1, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(X_test) 
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, grid_predictions)
from sklearn.metrics import classification_report
clf_report = classification_report(Y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(Y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 10.1, 'gamma': 'auto', 'kernel': 'sigmoid'}: 0.9924946382275899

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[51  0]
#  [ 1 81]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        51
#            1       1.00      0.99      0.99        82
#
#     accuracy                           0.99       133
#    macro avg       0.99      0.99      0.99       133
# weighted avg       0.99      0.99      0.99       133

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 1.0

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.022271      0.004773         0.028762        0.008351     10.1
# 1        0.024513      0.002182         0.029478        0.006508     10.1
# 2        0.033265      0.004533         0.026637        0.004852     10.1
# 3        0.016018      0.002663         0.026349        0.005133     10.1
# 4        0.014290      0.002054         0.027698        0.007334     10.1
# 5        0.022102      0.002285         0.028704        0.005682     10.1
# 6        0.035131      0.003629         0.025607        0.002998     10.1
# 7        0.018439      0.003840         0.028832        0.003170     10.1
# 8        0.018066      0.006173         0.024623        0.001401   1000.0
# 9        0.019526      0.004657         0.033745        0.004635   1000.0
# 10       0.032861      0.005631         0.026648        0.003295   1000.0
# 11       0.020325      0.003635         0.021942        0.001331   1000.0
# ...

# %% [markdown]
# age = float(input("Age: "))
# bp = float(input("BP: "))
# sg = float(input("SG (1.010/1.015/1.020/1.025): "))
# al = float(input("AL: "))
# su = float(input("SU: "))
#
# rbc = int(input("RBC normal=1, abnormal=0: "))
# pc = int(input("PC normal=1, abnormal=0: "))
# pcc = int(input("PCC present=1, notpresent=0: "))
# ba = int(input("BA present=1, notpresent=0: "))
#
# bgr = float(input("BGR: "))
# bu = float(input("BU: "))
# sc = float(input("SC: "))
# sod = float(input("SOD: "))
# pot = float(input("POT: "))
# hrmo = float(input("HGB/Hemo: "))
# pcv = float(input("PCV: "))
# wc = float(input("WC: "))
# rc = float(input("RC: "))
#
# htn = int(input("HTN yes=1, no=0: "))
# dm = int(input("DM yes=1, no=0: "))
# cad = int(input("CAD yes=1, no=0: "))
# appet = int(input("Appetite yes=1, no=0: "))
# pe = int(input("PE yes=1, no=0: "))
# ane = int(input("ANE yes=1, no=0: "))

# %%
# Manual Patient Input

age = 48
bp = 80
sg = 1.020
al = 1
su = 0

rbc = 1
pc = 1
pcc = 0
ba = 0

bgr = 121
bu = 36
sc = 1.2
sod = 138
pot = 4.5
hrmo = 15.4
pcv = 44
wc = 7800
rc = 5.2

htn = 1
dm = 0
cad = 0
appet = 1
pe = 0
ane = 0


# SG → Dummy Variables

sg_b = 1 if sg == 1.010 else 0
sg_c = 1 if sg == 1.015 else 0
sg_d = 1 if sg == 1.020 else 0
sg_e = 1 if sg == 1.025 else 0


# Create patient data
new_patient = [[
    age,
    bp,
    al,
    su,
    bgr,
    bu,
    sc,
    sod,
    pot,
    hrmo,
    pcv,
    wc,
    rc,
    sg_b,
    sg_c,
    sg_d,
    sg_e,
    rbc,
    pc,
    pcc,
    ba,
    htn,
    dm,
    cad,
    appet,
    pe,
    ane
]]


# Apply StandardScaler
preinput = scalar.transform(new_patient)


# Prediction
Future_Prediction = grid.predict(preinput)

print("Future_Prediction =", Future_Prediction)


# Result
if Future_Prediction[0] == 1:
    print("Result: CKD")
else:
    print("Result: NOT CKD")
# Out:
# Future_Prediction = [1]
# Result: CKD
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import pickle

# Save the trained GridSearch model
pickle.dump(grid, open("finalized_model_new_CKD.sav", "wb"))

# Save the StandardScaler
pickle.dump(scalar, open("scalar_CKD.sav", "wb"))

print("Model and Scalar saved successfully!")
# Out:
# Model and Scalar saved successfully!
